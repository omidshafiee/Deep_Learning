# %% [markdown]
# # Simple RNN

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Generate Dataset
# **Generate a sin series with additional noise**

# %%
samples = 1500
t = np.arange(0, samples)
x = np.sin(0.02 * t) + np.random.rand(samples) * 2
# x = np.sin(0.02 * t) + np.random.rand(samples)  *5
# x = np.sin(t)
plt.plot(x)

# %% [markdown]
# ### Split Tarin and test set
# **Select first 1000 element as train set, and the rest as test set**

# %%
train_quta = int(samples * 0.8)
# test_quta = int(samples * 0.2)

train, test = x[:train_quta], x[train_quta:]

# %% [markdown]
# ### Prepare data: Create Data and labels
# **NOTE: it is important for RNN to input data as a series, so a step must be consider for RNN**
# **We have to open time steps to solve the problem = Create bunch of time seriese which is known as unRoll**

# %%
step =10

# convert into daaset and labels
def convertToDataset(data, step):
#     data = np.append(data, np.repeat(data[-1,], step))
    x, y = [], []
    for i in range(len(data) - step):
        d = i + step
        x.append(data[i:d,])
        y.append(data[d,])
        
    return np.array(x), np.array(y)

# %%
trainX, trainy= convertToDataset(train, step)
testX, testy= convertToDataset(test, step)

# %%
print(trainX.shape)
print(trainy.shape)

print(testX.shape)
print(testy.shape)
# Out:
# (1190, 10)
# (1190,)
# (290, 10)
# (290,)

# %% [markdown]
# ## Modify data dimention to input into RNN
# ### RNN Input type in Keras is like:
# **(Number of Sequences, TimeSteps, Element perStep [Features])**<br/>
# **(Mini-Batch, unRoll,  number of Features)**

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(trainX.shape)
print(testX.shape)
# Out:
# (1190, 10, 1)
# (290, 10, 1)

# %% [markdown]
# ## Model Architecture and compile
# **Number of units = Hidden State Neurons**

# %%
model = Sequential()
model.add(SimpleRNN(units=64, activation="relu"))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')

# %%
# %%time
history = model.fit (trainX, trainy, epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 75/75 - 1s - loss: 0.4158 - 552ms/epoch - 7ms/step
# Epoch 2/100
# 75/75 - 0s - loss: 0.3765 - 57ms/epoch - 765us/step
# Epoch 3/100
# 75/75 - 0s - loss: 0.3768 - 77ms/epoch - 1ms/step
# Epoch 4/100
# 75/75 - 0s - loss: 0.3731 - 56ms/epoch - 748us/step
# Epoch 5/100
# 75/75 - 0s - loss: 0.3705 - 65ms/epoch - 871us/step
# Epoch 6/100
# 75/75 - 0s - loss: 0.3684 - 78ms/epoch - 1ms/step
# Epoch 7/100
# 75/75 - 0s - loss: 0.3716 - 64ms/epoch - 850us/step
# Epoch 8/100
# 75/75 - 0s - loss: 0.3620 - 63ms/epoch - 834us/step
# Epoch 9/100
# 75/75 - 0s - loss: 0.3617 - 65ms/epoch - 871us/step
# Epoch 10/100
# 75/75 - 0s - loss: 0.3586 - 78ms/epoch - 1ms/step
# Epoch 11/100
# 75/75 - 0s - loss: 0.3554 - 64ms/epoch - 849us/step
# Epoch 12/100
# 75/75 - 0s - loss: 0.3511 - 63ms/epoch - 837us/step
# Epoch 13/100
# 75/75 - 0s - loss: 0.3493 - 52ms/epoch - 692us/step
# Epoch 14/100
# 75/75 - 0s - loss: 0.3455 - 79ms/epoch - 1ms/step
# Epoch 15/100
# 75/75 - 0s - loss: 0.3433 - 64ms/epoch - 847us/step
# Epoch 16/100
# 75/75 - 0s - loss: 0.3424 - 63ms/epoch - 839us/step
# Epoch 17/100
# 75/75 - 0s - loss: 0.3357 - 63ms/epoch - 839us/step
# Epoch 18/100
# 75/75 - 0s - loss: 0.3327 - 71ms/epoch - 942us/step
# Epoch 19/100
# 75/75 - 0s - loss: 0.3319 - 64ms/epoch - 851us/step
# Epoch 20/100
# 75/75 - 0s - loss: 0.3267 - 65ms/epoch - 871us/step
# Epoch 21/100
# 75/75 - 0s - loss: 0.3204 - 63ms/epoch - 841us/step
# Epoch 22/100
# 75/75 - 0s - loss: 0.3172 - 74ms/epoch - 991us/step
# Epoch 23/100
# 75/75 - 0s - loss: 0.3174 - 63ms/epoch - 839us/step
# Epoch 24/100
# 75/75 - 0s - loss: 0.3139 - 63ms/epoch - 833us/step
# Epoch 25/100
# 75/75 - 0s - loss: 0.3082 - 63ms/epoch - 839us/step
# Epoch 26/100
# 75/75 - 0s - loss: 0.3036 - 63ms/epoch - 839us/step
# Epoch 27/100
# 75/75 - 0s - loss: 0.3030 - 71ms/epoch - 952us/step
# Epoch 28/100
# 75/75 - 0s - loss: 0.2956 - 63ms/epoch - 839us/step
# Epoch 29/100
# 75/75 - 0s - loss: 0.2962 - 63ms/epoch - 839us/step
# Epoch 30/100
# 75/75 - 0s - loss: 0.2960 - 63ms/epoch - 833us/step
# Epoch 31/100
# 75/75 - 0s - loss: 0.2892 - 79ms/epoch - 1ms/step
# Epoch 32/100
# 75/75 - 0s - loss: 0.2864 - 63ms/epoch - 839us/step
# Epoch 33/100
# 75/75 - 0s - loss: 0.2821 - 63ms/epoch - 833us/step
# Epoch 34/100
# 75/75 - 0s - loss: 0.2783 - 63ms/epoch - 839us/step
# Epoch 35/100
# 75/75 - 0s - loss: 0.2752 - 68ms/epoch - 900us/step
# Epoch 36/100
# 75/75 - 0s - loss: 0.2699 - 75ms/epoch - 994us/step
# Epoch 37/100
# 75/75 - 0s - loss: 0.2706 - 63ms/epoch - 840us/step
# Epoch 38/100
# 75/75 - 0s - loss: 0.2660 - 63ms/epoch - 839us/step
# Epoch 39/100
# 75/75 - 0s - loss: 0.2616 - 63ms/epoch - 833us/step
# Epoch 40/100
# 75/75 - 0s - loss: 0.2644 - 63ms/epoch - 839us/step
# Epoch 41/100
# 75/75 - 0s - loss: 0.2622 - 75ms/epoch - 996us/step
# Epoch 42/100
# 75/75 - 0s - loss: 0.2539 - 65ms/epoch - 864us/step
# Epoch 43/100
# 75/75 - 0s - loss: 0.2567 - 61ms/epoch - 818us/step
# Epoch 44/100
# 75/75 - 0s - loss: 0.2518 - 69ms/epoch - 921us/step
# Epoch 45/100
# 75/75 - 0s - loss: 0.2491 - 56ms/epoch - 752us/step
# Epoch 46/100
# 75/75 - 0s - loss: 0.2469 - 68ms/epoch - 902us/step
# Epoch 47/100
# 75/75 - 0s - loss: 0.2420 - 76ms/epoch - 1ms/step
# Epoch 48/100
# 75/75 - 0s - loss: 0.2433 - 65ms/epoch - 867us/step
# Epoch 49/100
# 75/75 - 0s - loss: 0.2393 - 63ms/epoch - 839us/step
# Epoch 50/100
# 75/75 - 0s - loss: 0.2396 - 73ms/epoch - 967us/step
# Epoch 51/100
# 75/75 - 0s - loss: 0.2362 - 69ms/epoch - 914us/step
# Epoch 52/100
# 75/75 - 0s - loss: 0.2335 - 68ms/epoch - 902us/step
# Epoch 53/100
# 75/75 - 0s - loss: 0.2311 - 64ms/epoch - 857us/step
# Epoch 54/100
# 75/75 - 0s - loss: 0.2270 - 69ms/epoch - 921us/step
# Epoch 55/100
# 75/75 - 0s - loss: 0.2238 - 78ms/epoch - 1ms/step
# Epoch 56/100
# 75/75 - 0s - loss: 0.2213 - 63ms/epoch - 839us/step
# Epoch 57/100
# 75/75 - 0s - loss: 0.2226 - 64ms/epoch - 848us/step
# Epoch 58/100
# 75/75 - 0s - loss: 0.2177 - 63ms/epoch - 839us/step
# Epoch 59/100
# 75/75 - 0s - loss: 0.2167 - 64ms/epoch - 860us/step
# Epoch 60/100
# 75/75 - 0s - loss: 0.2142 - 63ms/epoch - 834us/step
# Epoch 61/100
# 75/75 - 0s - loss: 0.2085 - 63ms/epoch - 839us/step
# Epoch 62/100
# 75/75 - 0s - loss: 0.2085 - 74ms/epoch - 990us/step
# Epoch 63/100
# 75/75 - 0s - loss: 0.2108 - 52ms/epoch - 692us/step
# Epoch 64/100
# 75/75 - 0s - loss: 0.2006 - 63ms/epoch - 841us/step
# Epoch 65/100
# 75/75 - 0s - loss: 0.2054 - 62ms/epoch - 833us/step
# Epoch 66/100
# 75/75 - 0s - loss: 0.2067 - 63ms/epoch - 839us/step
# Epoch 67/100
# 75/75 - 0s - loss: 0.1973 - 63ms/epoch - 839us/step
# Epoch 68/100
# 75/75 - 0s - loss: 0.1968 - 63ms/epoch - 838us/step
# Epoch 69/100
# 75/75 - 0s - loss: 0.1979 - 63ms/epoch - 834us/step
# Epoch 70/100
# 75/75 - 0s - loss: 0.1933 - 63ms/epoch - 839us/step
# Epoch 71/100
# 75/75 - 0s - loss: 0.1917 - 63ms/epoch - 833us/step
# Epoch 72/100
# 75/75 - 0s - loss: 0.1945 - 78ms/epoch - 1ms/step
# Epoch 73/100
# 75/75 - 0s - loss: 0.1870 - 63ms/epoch - 845us/step
# Epoch 74/100
# 75/75 - 0s - loss: 0.1904 - 63ms/epoch - 833us/step
# Epoch 75/100
# 75/75 - 0s - loss: 0.1873 - 63ms/epoch - 839us/step
# Epoch 76/100
# 75/75 - 0s - loss: 0.1833 - 64ms/epoch - 854us/step
# Epoch 77/100
# 75/75 - 0s - loss: 0.1823 - 62ms/epoch - 832us/step
# Epoch 78/100
# 75/75 - 0s - loss: 0.1825 - 63ms/epoch - 839us/step
# Epoch 79/100
# 75/75 - 0s - loss: 0.1799 - 63ms/epoch - 833us/step
# Epoch 80/100
# 75/75 - 0s - loss: 0.1742 - 50ms/epoch - 672us/step
# Epoch 81/100
# 75/75 - 0s - loss: 0.1776 - 79ms/epoch - 1ms/step
# Epoch 82/100
# 75/75 - 0s - loss: 0.1730 - 62ms/epoch - 833us/step
# Epoch 83/100
# 75/75 - 0s - loss: 0.1714 - 63ms/epoch - 839us/step
# Epoch 84/100
# 75/75 - 0s - loss: 0.1710 - 63ms/epoch - 839us/step
# Epoch 85/100
# 75/75 - 0s - loss: 0.1660 - 63ms/epoch - 833us/step
# Epoch 86/100
# 75/75 - 0s - loss: 0.1675 - 63ms/epoch - 839us/step
# Epoch 87/100
# 75/75 - 0s - loss: 0.1674 - 63ms/epoch - 839us/step
# Epoch 88/100
# 75/75 - 0s - loss: 0.1599 - 72ms/epoch - 964us/step
# Epoch 89/100
# 75/75 - 0s - loss: 0.1617 - 70ms/epoch - 932us/step
# Epoch 90/100
# 75/75 - 0s - loss: 0.1570 - 63ms/epoch - 839us/step
# Epoch 91/100
# 75/75 - 0s - loss: 0.1553 - 63ms/epoch - 845us/step
# Epoch 92/100
# 75/75 - 0s - loss: 0.1543 - 63ms/epoch - 839us/step
# Epoch 93/100
# 75/75 - 0s - loss: 0.1523 - 65ms/epoch - 860us/step
# Epoch 94/100
# 75/75 - 0s - loss: 0.1562 - 61ms/epoch - 812us/step
# Epoch 95/100
# 75/75 - 0s - loss: 0.1488 - 49ms/epoch - 652us/step
# Epoch 96/100
# 75/75 - 0s - loss: 0.1464 - 63ms/epoch - 838us/step
# Epoch 97/100
# 75/75 - 0s - loss: 0.1496 - 63ms/epoch - 833us/step
# Epoch 98/100
# 75/75 - 0s - loss: 0.1435 - 64ms/epoch - 853us/step
# Epoch 99/100
# 75/75 - 0s - loss: 0.1437 - 63ms/epoch - 833us/step
# Epoch 100/100
# 75/75 - 0s - loss: 0.1462 - 55ms/epoch - 732us/step
# CPU times: total: 15.8 s
# Wall time: 7.1 s

# %%
# Must specify input shape or fit the model before run this command
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 4,289
# Trainable params: 4,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 10, 1) dtype=float32 (created by layer 'simple_rnn_input')>

# %% [markdown]
# ## Model Evaluation

# %%
history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss = history.history['loss']
plt.plot(loss, label='Training Loss')
plt.legend()

# %%
trainScore = model.evaluate(trainX, trainy, verbose=0)
print(trainScore)

testScore = model.evaluate(testX, testy, verbose=0)
print(testScore)
# Out:
# 0.13450086116790771
# 0.5285547971725464

# %% [markdown]
# ## Prediction

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

predict = np.concatenate((trainPredict, testPredict), axis=0)
# Out:
# 38/38 [==============================] - 0s 365us/step
# 10/10 [==============================] - 0s 0s/step

# %%
plt.plot(x, color='blue')
plt.plot(predict, color='orange')
plt.axvline(len(trainX), color='r')
plt.show()

# %% [markdown]
# ## Input with different shape

# %%
testX, testY = convertToDataset(test, 50)

# %%
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
testX.shape
# Out:
# (250, 50, 1)

# %%
testPredict = model.predict(testX)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
plt.plot(x, color='blue')
plt.plot(test, color='orange')
