# %% [markdown]
# # Simple RNN

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Generate Dataset
# **Generate a sin series with additional noise**

# %%
samples = 5000
t = np.arange(0, samples)
x = np.sin(0.02 * t) + np.random.rand(samples) * 3
# x = np.sin(0.02 * t) + np.random.rand(1500)  *5
plt.plot(x)

# %% [markdown]
# ### Split Tarin and test set
# **Select first 1000 element as train set, and the rest as test set**

# %%
train, test = x[:4000], x[4000:]

# %% [markdown]
# ### Prepare data: Create Data and labels
# **NOTE: it is important for RNN to input data as a series, so a step must be consider for RNN**
# **We have to open time steps to solve the problem = Create bunch of time seriese which is known as unRoll**

# %%
step =10

# convert into daaset and labels
def convertToDataset(data, step):
#     data = np.append(data, np.repeat(data[-1,], step))
    x, y = [], []
    for i in range(len(data) - step):
        d = i + step
        x.append(data[i:d,])
        y.append(data[d,])
        
    return np.array(x), np.array(y)

# %%
trainX, trainy= convertToDataset(train, step)
testX, testy= convertToDataset(test, step)

# %%
print(trainX.shape)
print(trainy.shape)

print(testX.shape)
print(testy.shape)
# Out:
# (3990, 10)
# (3990,)
# (990, 10)
# (990,)

# %% [markdown]
# ## Modify data dimention to input into RNN
# ### RNN Input type in Keras is like:
# **(Number of Sequences, TimeSteps, Element perStep [Features])**<br/>
# **(Mini-Batch, unRoll,  number of Features)**

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
print(trainX.shape)
print(testX.shape)
# Out:
# (3990, 10, 1)
# (990, 10, 1)

# %% [markdown]
# ## Model Architecture and compile
# **Number of units = Hidden State Neurons**

# %%
model = Sequential()
model.add(SimpleRNN(units=64, activation="tanh"))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')

# %%
# %% time
# history = model.fit (trainX, trainy, epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 250/250 - 1s - loss: 0.9909 - 568ms/epoch - 2ms/step
# Epoch 2/100
# 250/250 - 0s - loss: 0.8479 - 204ms/epoch - 816us/step
# Epoch 3/100
# 250/250 - 0s - loss: 0.8322 - 205ms/epoch - 820us/step
# Epoch 4/100
# 250/250 - 0s - loss: 0.8298 - 219ms/epoch - 877us/step
# Epoch 5/100
# 250/250 - 0s - loss: 0.8264 - 204ms/epoch - 817us/step
# Epoch 6/100
# 250/250 - 0s - loss: 0.8245 - 200ms/epoch - 800us/step
# Epoch 7/100
# 250/250 - 0s - loss: 0.8189 - 203ms/epoch - 813us/step
# Epoch 8/100
# 250/250 - 0s - loss: 0.8260 - 205ms/epoch - 820us/step
# Epoch 9/100
# 250/250 - 0s - loss: 0.8168 - 220ms/epoch - 879us/step
# Epoch 10/100
# 250/250 - 0s - loss: 0.8120 - 204ms/epoch - 816us/step
# Epoch 11/100
# 250/250 - 0s - loss: 0.8137 - 204ms/epoch - 816us/step
# Epoch 12/100
# 250/250 - 0s - loss: 0.8095 - 220ms/epoch - 878us/step
# Epoch 13/100
# 250/250 - 0s - loss: 0.8105 - 206ms/epoch - 823us/step
# Epoch 14/100
# 250/250 - 0s - loss: 0.8072 - 211ms/epoch - 844us/step
# Epoch 15/100
# 250/250 - 0s - loss: 0.8055 - 201ms/epoch - 803us/step
# Epoch 16/100
# 250/250 - 0s - loss: 0.8043 - 220ms/epoch - 878us/step
# Epoch 17/100
# 250/250 - 0s - loss: 0.8015 - 214ms/epoch - 857us/step
# Epoch 18/100
# 250/250 - 0s - loss: 0.7967 - 196ms/epoch - 784us/step
# Epoch 19/100
# 250/250 - 0s - loss: 0.8007 - 220ms/epoch - 879us/step
# Epoch 20/100
# 250/250 - 0s - loss: 0.7984 - 204ms/epoch - 816us/step
# Epoch 21/100
# 250/250 - 0s - loss: 0.7948 - 219ms/epoch - 876us/step
# Epoch 22/100
# 250/250 - 0s - loss: 0.7879 - 206ms/epoch - 823us/step
# Epoch 23/100
# 250/250 - 0s - loss: 0.7857 - 206ms/epoch - 822us/step
# Epoch 24/100
# 250/250 - 0s - loss: 0.7798 - 218ms/epoch - 872us/step
# Epoch 25/100
# 250/250 - 0s - loss: 0.7804 - 216ms/epoch - 863us/step
# Epoch 26/100
# 250/250 - 0s - loss: 0.7794 - 204ms/epoch - 815us/step
# Epoch 27/100
# 250/250 - 0s - loss: 0.7742 - 205ms/epoch - 822us/step
# Epoch 28/100
# 250/250 - 0s - loss: 0.7718 - 204ms/epoch - 816us/step
# Epoch 29/100
# 250/250 - 0s - loss: 0.7643 - 203ms/epoch - 814us/step
# Epoch 30/100
# 250/250 - 0s - loss: 0.7619 - 204ms/epoch - 816us/step
# Epoch 31/100
# 250/250 - 0s - loss: 0.7584 - 209ms/epoch - 838us/step
# Epoch 32/100
# 250/250 - 0s - loss: 0.7514 - 206ms/epoch - 823us/step
# Epoch 33/100
# 250/250 - 0s - loss: 0.7480 - 220ms/epoch - 878us/step
# Epoch 34/100
# 250/250 - 0s - loss: 0.7405 - 204ms/epoch - 816us/step
# Epoch 35/100
# 250/250 - 0s - loss: 0.7344 - 204ms/epoch - 816us/step
# Epoch 36/100
# 250/250 - 0s - loss: 0.7341 - 225ms/epoch - 899us/step
# Epoch 37/100
# 250/250 - 0s - loss: 0.7260 - 216ms/epoch - 862us/step
# Epoch 38/100
# 250/250 - 0s - loss: 0.7181 - 204ms/epoch - 816us/step
# Epoch 39/100
# 250/250 - 0s - loss: 0.7136 - 220ms/epoch - 878us/step
# Epoch 40/100
# 250/250 - 0s - loss: 0.7101 - 206ms/epoch - 826us/step
# Epoch 41/100
# 250/250 - 0s - loss: 0.7003 - 198ms/epoch - 792us/step
# Epoch 42/100
# 250/250 - 0s - loss: 0.6972 - 205ms/epoch - 819us/step
# Epoch 43/100
# 250/250 - 0s - loss: 0.6865 - 219ms/epoch - 877us/step
# Epoch 44/100
# 250/250 - 0s - loss: 0.6857 - 204ms/epoch - 816us/step
# Epoch 45/100
# 250/250 - 0s - loss: 0.6787 - 204ms/epoch - 816us/step
# Epoch 46/100
# 250/250 - 0s - loss: 0.6736 - 196ms/epoch - 784us/step
# Epoch 47/100
# 250/250 - 0s - loss: 0.6705 - 205ms/epoch - 822us/step
# Epoch 48/100
# 250/250 - 0s - loss: 0.6570 - 215ms/epoch - 859us/step
# Epoch 49/100
# 250/250 - 0s - loss: 0.6506 - 201ms/epoch - 802us/step
# Epoch 50/100
# 250/250 - 0s - loss: 0.6458 - 204ms/epoch - 817us/step
# Epoch 51/100
# 250/250 - 0s - loss: 0.6386 - 221ms/epoch - 882us/step
# Epoch 52/100
# 250/250 - 0s - loss: 0.6287 - 208ms/epoch - 831us/step
# Epoch 53/100
# 250/250 - 0s - loss: 0.6261 - 205ms/epoch - 819us/step
# Epoch 54/100
# 250/250 - 0s - loss: 0.6159 - 220ms/epoch - 879us/step
# Epoch 55/100
# 250/250 - 0s - loss: 0.6087 - 204ms/epoch - 816us/step
# Epoch 56/100
# 250/250 - 0s - loss: 0.5989 - 205ms/epoch - 820us/step
# Epoch 57/100
# 250/250 - 0s - loss: 0.5911 - 204ms/epoch - 816us/step
# Epoch 58/100
# 250/250 - 0s - loss: 0.5881 - 218ms/epoch - 871us/step
# Epoch 59/100
# 250/250 - 0s - loss: 0.5786 - 203ms/epoch - 814us/step
# Epoch 60/100
# 250/250 - 0s - loss: 0.5679 - 206ms/epoch - 826us/step
# Epoch 61/100
# 250/250 - 0s - loss: 0.5608 - 206ms/epoch - 822us/step
# Epoch 62/100
# 250/250 - 0s - loss: 0.5534 - 204ms/epoch - 816us/step
# Epoch 63/100

# %%
# Must specify input shape or fit the model before run this command
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 64)                4224
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,289
# Trainable params: 4,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 10, 1) dtype=float32 (created by layer 'simple_rnn_3_input')>

# %% [markdown]
# ## Model Evaluation

# %%
history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss = history.history['loss']
plt.plot(loss, label='Training Loss')
plt.legend()

# %%
trainScore = model.evaluate(trainX, trainy, verbose=0)
print(trainScore)

testScore = model.evaluate(testX, testy, verbose=0)
print(testScore)
# Out:
# 0.12037630379199982
# 1.3478814363479614

# %% [markdown]
# ## Prediction

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

predict = np.concatenate((trainPredict, testPredict), axis=0)
# Out:
# 31/31 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step

# %%
plt.plot(x)
plt.plot(predict)
plt.axvline(len(trainX), color='r')
plt.show()
