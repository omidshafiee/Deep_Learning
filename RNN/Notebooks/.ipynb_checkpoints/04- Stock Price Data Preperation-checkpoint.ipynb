# %%
import numpy as np
import pandas as pd

from datetime import datetime
import os
import glob

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = os.path.join("D:",os.sep, "Datasets","Stock","h1")#, "*.csv")
# os.listdir(path)

# %% [markdown]
#     # read all data into 1 dataframed
# df_list = []
# for (root, dirs ,files) in os.walk(path):
#     # df_list = (pd.read_csv(os.path.join(path,f), delimiter='\t') for file in files)
#     # big_df= pd.concat(df_list, ignore_index=True)
#     for f in files:
#         df_tmp = pd.read_csv(os.path.join(path,f), delimiter='\t')
#         df_tmp['Instrument'] = f.split('_')[0]
#         df_list.append(df_tmp)
#         print(f.split('_')[0] + ' has updated!')
#
# df= pd.concat(df_list, ignore_index=True)

# %%
# read all data into 1 dataframed
df_list = []
for (root, dirs ,files) in os.walk(path):
    # df_list = (pd.read_csv(os.path.join(path,f), delimiter='\t') for file in files)
    # big_df= pd.concat(df_list, ignore_index=True)
    for f in files:
        df_tmp = pd.read_csv(os.path.join(path,f), delimiter='\t')
        df_tmp['Instrument'] = f.split('_')[0]
        df_list.append(df_tmp)
        print(f.split('_')[0] + ' has updated!')

df= pd.concat(df_list, ignore_index=True)

df.to_csv('../Dataset/stock.csv', index=None)
# Out:
# EURGBP has updated!
# EURUSD has updated!
# GBPUSD has updated!
# USDJPY has updated!

# %%
df['Instrument'].value_counts()
# Out:
# USDJPY    100026
# EURUSD    100009
# EURGBP    100006
# GBPUSD    100006
# Name: Instrument, dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Instrument'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400047 entries, 0 to 400046
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Time        400047 non-null  object
#  1   Open        400047 non-null  float64
#  2   High        400047 non-null  float64
#  3   Low         400047 non-null  float64
#  4   Close       400047 non-null  float64
#  5   Volume      400047 non-null  int64
#  6   Instrument  400047 non-null  object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 21.4+ MB

# %%
df
# Out:
#                        Time       Open      High        Low      Close  \
# 0       2007-07-24 18:00:00    0.67010    0.6701    0.66966    0.67000
# 1       2007-07-24 19:00:00    0.67000    0.6707    0.66985    0.67045
# 2       2007-07-24 20:00:00    0.67045    0.6706    0.66990    0.67010
# 3       2007-07-24 21:00:00    0.67010    0.6707    0.66990    0.67050
# 4       2007-07-24 22:00:00    0.67050    0.6707    0.67032    0.67040
# ...                     ...        ...       ...        ...        ...
# 400042  2023-08-01 00:00:00  142.32400  142.5010  142.25400  142.49600
# 400043  2023-08-01 01:00:00  142.49400  142.7840  142.43400  142.75300
# 400044  2023-08-01 02:00:00  142.76500  142.7960  142.53200  142.57300
# 400045  2023-08-01 03:00:00  142.57400  142.7260  142.53800  142.66700
# 400046  2023-08-01 04:00:00  142.66800  142.8430  142.64900  142.72100
#
#         Volume Instrument
# 0        15421     EURGBP
# 1        84904     EURGBP
# 2        33690     EURGBP
# 3         8960     EURGBP
# 4        16738     EURGBP
# ...        ...        ...
# 400042   11202     USDJPY
# 400043   14572     USDJPY
# 400044   11623     USDJPY
# 400045    7933     USDJPY
# 400046    8360     USDJPY
#
# [400047 rows x 7 columns]

# %% [markdown]
# ## Create 4 Instrument low price dataframe

# %%
col_name = ['USDJPY_Low']
df_lows = pd.DataFrame(df[df['Instrument'] == 'USDJPY'][['Time', 'Low']])

# %%
df_lows.join(df[df['Instrument'] == 'EURGBP']['Low'], how='left' ,lsuffix='_left', rsuffix='_right')
# Out:
#                        Time  Low_left  Low_right
# 300021  2007-07-04 07:00:00   122.340        NaN
# 300022  2007-07-04 08:00:00   122.360        NaN
# 300023  2007-07-04 09:00:00   122.390        NaN
# 300024  2007-07-04 10:00:00   122.450        NaN
# 300025  2007-07-04 11:00:00   122.470        NaN
# ...                     ...       ...        ...
# 400042  2023-08-01 00:00:00   142.254        NaN
# 400043  2023-08-01 01:00:00   142.434        NaN
# 400044  2023-08-01 02:00:00   142.532        NaN
# 400045  2023-08-01 03:00:00   142.538        NaN
# 400046  2023-08-01 04:00:00   142.649        NaN
#
# [100026 rows x 3 columns]

# %%
df_EURGBP = pd.read_csv('../../../../Datasets/Stock/h1/EURGBP_H1.csv', delimiter='\t')
df_EURUSD = pd.read_csv('../../../../Datasets/Stock/h1/EURUSD_H1.csv', delimiter='\t')

# %%
df_tot =  df_EURGBP.merge(df_EURUSD, on='Time' ,how='inner')

# %%
df_tot
# Out:
#                       Time   Open_x   High_x    Low_x  Close_x  Volume_x  \
# 0      2007-07-24 23:00:00  0.67040  0.67060  0.67006  0.67050     12965
# 1      2007-07-25 00:00:00  0.67050  0.67120  0.67030  0.67115     54775
# 2      2007-07-25 01:00:00  0.67115  0.67135  0.67075  0.67090     47373
# 3      2007-07-25 02:00:00  0.67090  0.67100  0.67070  0.67080     22591
# 4      2007-07-25 03:00:00  0.67080  0.67090  0.67055  0.67080     25924
# ...                    ...      ...      ...      ...      ...       ...
# 99991  2023-08-01 00:00:00  0.85696  0.85708  0.85647  0.85652      1693
# 99992  2023-08-01 01:00:00  0.85651  0.85698  0.85645  0.85693      2121
# 99993  2023-08-01 02:00:00  0.85694  0.85702  0.85669  0.85684      1779
# 99994  2023-08-01 03:00:00  0.85686  0.85691  0.85668  0.85674      1727
# 99995  2023-08-01 04:00:00  0.85675  0.85686  0.85615  0.85642      1805
#
#         Open_y   High_y    Low_y  Close_y  Volume_y
# 0      1.38231  1.38292  1.38143  1.38195     12756
# 1      1.38179  1.38199  1.37991  1.38042     28436
# 2      1.38008  1.38134  1.37975  1.38084     24413
# 3      1.38089  1.38144  1.37988  1.38077     24666
# 4      1.38086  1.38121  1.37977  1.38057     17857
# ...        ...      ...      ...      ...       ...
# 99991  1.09967  1.10015  1.09882  1.09888      9990
# 99992  1.09887  1.09908  1.09840  1.09859      9877
# 99993  1.09858  1.09870  1.09803  1.09850      7947
# 99994  1.09853  1.09890  1.09839  1.09855      6362
# 99995  1.09854  1.09910  1.09819  1.09900      8437
#
# [99996 rows x 11 columns]

# %%
# Visually check for null values
sns.heatmap(df_tot.notnull())
# Out:
# <Axes: >

# %%
df['time'].min()
# Out:
# '2007-07-24 08:00'

# %%
df['']
